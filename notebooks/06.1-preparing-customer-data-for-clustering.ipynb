# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# import the libraries needed

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
online_retail_history = pd.read_pickle("../data/online_history_cleaned.pkl")

# %%
# preview the data

online_retail_history.head()
# Out:
#   Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 0  536365    85123A         6 2010-12-01 08:26:00   2.55      u1785
# 1  536365     71053         6 2010-12-01 08:26:00   3.39      u1785
# 2  536365    84406B         8 2010-12-01 08:26:00   2.75      u1785
# 3  536365    84029G         6 2010-12-01 08:26:00   3.39      u1785
# 4  536365    84029E         6 2010-12-01 08:26:00   3.39      u1785
#
#           Country                          Description
# 0  United Kingdom   CREAM HANGING HEART T-LIGHT HOLDER
# 1  United Kingdom         WHITE MOROCCAN METAL LANTERN
# 2  United Kingdom       CREAM CUPID HEARTS COAT HANGER
# 3  United Kingdom  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  United Kingdom       RED WOOLLY HOTTIE WHITE HEART.

# %%
# check shape of the data

online_retail_history.shape

# is this the same as the file we saved?
# Out:
# (397925, 8)

# %% [markdown]
# ## Exploring the data

# %%
# check how many orders, products and customers in the dataset

print("Number of unique customers:", len(online_retail_history.CustomerID.unique()))
print("Number of unique invoices:", len(online_retail_history.Invoice.unique()))
print("Number of unique products:", len(online_retail_history.StockCode.unique()))
# Out:
# Number of unique customers: 4339
# Number of unique invoices: 18536
# Number of unique products: 3665

# %%
print("The most expensive product Price:", online_retail_history.Price.max())
print("The average price of a Product:", round(online_retail_history.Price.mean(), 2))
print("Total Number of Items sold:", online_retail_history.Quantity.sum())

# Signs of outliers... Let's not go into this now. If interested,
# I will share a notebook with detailed explorative work.
# Out:
# The most expensive product Price: 8142.75
# The average price of a Product: 3.12
# Total Number of Items sold: 5181697

# %%
# hmm, looks like the data is corrupted , let's remove all examples where price and quantity is an outlier

online_retail_history[online_retail_history.Price == online_retail_history.Price.max()]
# Out:
#        Invoice StockCode  Quantity         InvoiceDate    Price CustomerID  \
# 169617  551697      POST         1 2011-05-03 13:46:00  8142.75     u16029
#
#                Country Description
# 169617  United Kingdom     POSTAGE

# %%
online_retail_history.Price.hist();

# %%
def calc_outliers(var):
    Q3 = np.percentile(var, 75) 
    Q1 = np.percentile(var, 25)

    print("upper quartile:", Q3,  
        "\nlower quartile:", Q1)
  
    IQR = 1.5*(Q3 - Q1)

    LB = Q1 - IQR
    UB = Q3 + IQR

    print("Lower Bound of outliers:", round(LB, 2), "\nUpper Bound of outliers:", round(UB, 2)) 

    return LB, UB

# %%
LB, UB = calc_outliers(online_retail_history.Price)
# Out:
# upper quartile: 3.75
# lower quartile: 1.25
# Lower Bound of outliers: -2.5
# Upper Bound of outliers: 7.5

# %%
# remove all examples of outliers

print(online_retail_history.shape)
online_retail_history_cleaned = online_retail_history[(online_retail_history.Price > LB) & (online_retail_history.Price < UB)]
print(online_retail_history_cleaned.shape)
# Out:
# (397925, 8)
# (362980, 8)

# %%
# check cleaning took place

online_retail_history_cleaned.Price.describe()
# Out:
# count    362980.000000
# mean          2.125971
# std           1.520801
# min           0.000000
# 25%           0.850000
# 50%           1.650000
# 75%           2.950000
# max           7.460000
# Name: Price, dtype: float64

# %%
# you could do the same for Quantity and other variables, but will save that for another iteration.

# %%
# check how many times postage appears

online_retail_history_cleaned[online_retail_history_cleaned.Description == "POSTAGE"]
# Out:
#        Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 127662  547444      POST         1 2011-03-23 10:55:00   1.00     u12811
# 149458  549689      POST         1 2011-04-11 13:40:00   4.95     u15971
# 169354  551652      POST         2 2011-05-03 12:03:00   1.00     u12643
# 201887  554924      POST         1 2011-05-27 12:54:00   4.00     u12748
# 219648  556519      POST         1 2011-06-13 10:54:00   2.02     u16794
# 270654  561057      POST         1 2011-07-24 13:18:00   2.90     u17935
# 281010  562047      POST         1 2011-08-02 10:38:00   4.95     u17788
# 354491  568398      POST         1 2011-09-27 10:26:00   5.00     u14543
# 361821  569033      POST         1 2011-09-30 10:40:00   6.00     u15611
# 383600  570681      POST         1 2011-10-11 15:45:00   6.00     u12381
# 384622  570725      POST         1 2011-10-12 11:30:00   4.50     u12381
# 482319  578099      POST         2 2011-11-23 08:05:00   1.00     u12452
# 482604  578126      POST         1 2011-11-23 10:32:00   4.95       u169
# 516955  580705      POST         5 2011-12-05 16:28:00   1.00     u12683
#
#                Country Description
# 127662        Portugal     POSTAGE
# 149458  United Kingdom     POSTAGE
# 169354          France     POSTAGE
# 201887  United Kingdom     POSTAGE
# 219648  United Kingdom     POSTAGE
# 270654  United Kingdom     POSTAGE
# 281010  United Kingdom     POSTAGE
# 354491  United Kingdom     POSTAGE
# 361821  United Kingdom     POSTAGE
# 383600          Norway     POSTAGE
# 384622          Norway     POSTAGE
# 482319     Switzerland     POSTAGE
# 482604  United Kingdom     POSTAGE
# 516955          France     POSTAGE

# %%
# remove postage from the data

print(online_retail_history_cleaned.shape)
online_retail_history_cleaned[online_retail_history_cleaned.StockCode != "POST"]
print(online_retail_history_cleaned.shape)

# there may be more redundant stock codes, but would need more exploring
# Out:
# (362980, 8)
# (362980, 8)

# %%
# top 50 products 

online_retail_history_cleaned.Description.value_counts().nlargest(50)
# Out:
# CREAM HANGING HEART T-LIGHT HOLDER     2035
# JUMBO BAG RED RETROSPOT                1618
# ASSORTED COLOUR BIRD ORNAMENT          1408
# PARTY BUNTING                          1394
# LUNCH BAG RED RETROSPOT                1317
# Unknown Stock                          1280
# SET OF 3 CAKE TINS PANTRY DESIGN       1151
# LUNCH BAG  BLACK SKULL.                1105
# JUMBO BAG VINTAGE DOILEY               1098
# LUNCH BAG SUKI DESIGN                  1083
# PACK OF 72 RETROSPOT CAKE CASES        1068
# POPCORN HOLDER                         1068
# LUNCH BAG VINTAGE DOILEY               1029
# BUNTING , SPOTTY                       1024
# PAPER CHAIN KIT 50'S CHRISTMAS         1019
# LUNCH BAG SPACEBOY DESIGN              1008
# LUNCH BAG CARS BLUE                     989
# HEART OF WICKER SMALL                   985
# NATURAL SLATE HEART CHALKBOARD          980
# LUNCH BAG PINK POLKADOT                 957
# REX CASH+CARRY JUMBO SHOPPER            952
# ALARM CLOCK BAKELIKE RED                899
# LUNCH BAG APPLE DESIGN                  895
# SET OF 4 PANTRY JELLY MOULDS            893
# JUMBO BAG PINK POLKADOT                 890
# WOODEN PICTURE FRAME WHITE FINISH       887
# JAM MAKING SET WITH JARS                878
# JAM MAKING SET PRINTED                  875
# BAKING SET 9 PIECE RETROSPOT            856
# RECIPE BOX PANTRY YELLOW DESIGN         843
# LUNCH BAG WOODLAND                      842
# RABBIT NIGHT LIGHT                      842
# VICTORIAN GLASS HANGING T-LIGHT         825
# RETROSPOT TEA SET CERAMIC 11 PC         821
# WOODEN FRAME ANTIQUE WHITE              820
# HEART OF WICKER LARGE                   819
# ALARM CLOCK BAKELIKE GREEN              808
# JUMBO SHOPPER VINTAGE RED PAISLEY       803
# ROSES REGENCY TEACUP AND SAUCER         801
# SET/5 RED RETROSPOT LID GLASS BOWLS     784
# JUMBO STORAGE BAG SUKI                  783
# JUMBO BAG VINTAGE LEAF                  782
# GARDENERS KNEELING PAD KEEP CALM        768
# JUMBO BAG ALPHABET                      761
# SET/20 RED RETROSPOT PAPER NAPKINS      753
# 6 RIBBONS RUSTIC CHARM                  751
# RED RETROSPOT CHARLOTTE BAG             751
# HOT WATER BOTTLE KEEP CALM              740
# VINTAGE SNAP CARDS                      736
# JUMBO BAG APPLES                        726
# Name: Description, dtype: int64

# %%
print(online_retail_history_cleaned.shape)
online_retail_history_cleaned = online_retail_history_cleaned[~online_retail_history_cleaned.Description.isin(["POST", "Unknown Stock"])]
print(online_retail_history_cleaned.shape)
# Out:
# (362980, 8)
# (361700, 8)

# %%
# look at the different target markets 
# let's assume different target markets behave differently and have different types of customers

online_retail_history.Country.value_counts()
# Out:
# United Kingdom          354345
# Germany                   9042
# France                    8343
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     17
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
# can validate my assumption by for e.g. looking at the price distribution across target markets
# you could look at different products bought across different markets
# You could also look at Quantity distribution


countries = online_retail_history_cleaned["Country"].unique() # extracting unique country names

# plotting the violin plot for the data
fig, ax = plt.subplots(10, 4, figsize=(18,20))
axes_ = [axes_row for axes in ax for axes_row in axes]

for i, c in enumerate(countries):
    sns.violinplot(x = "Price", data = online_retail_history_cleaned[online_retail_history_cleaned["Country"] == c], ax = axes_[i], inner = "point", palette = "pastel")
    axes_[i].set_title(c + ' ' + "Price Distribution")
    plt.tight_layout()

    
# UK and France seem to have similar distributions, so maybe my assumption is not true but let's start with it...

# %%
# look at a market of our choicem let's start with the largest market

UK_online_history = online_retail_history_cleaned[online_retail_history_cleaned.Country == 'United Kingdom']

UK_online_history.head()

# check the Country column
# Out:
#   Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 0  536365    85123A         6 2010-12-01 08:26:00   2.55      u1785
# 1  536365     71053         6 2010-12-01 08:26:00   3.39      u1785
# 2  536365    84406B         8 2010-12-01 08:26:00   2.75      u1785
# 3  536365    84029G         6 2010-12-01 08:26:00   3.39      u1785
# 4  536365    84029E         6 2010-12-01 08:26:00   3.39      u1785
#
#           Country                          Description
# 0  United Kingdom   CREAM HANGING HEART T-LIGHT HOLDER
# 1  United Kingdom         WHITE MOROCCAN METAL LANTERN
# 2  United Kingdom       CREAM CUPID HEARTS COAT HANGER
# 3  United Kingdom  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  United Kingdom       RED WOOLLY HOTTIE WHITE HEART.

# %%
UK_online_history.Country.value_counts()
# Out:
# United Kingdom    323471
# Name: Country, dtype: int64

# %%
# check the size of our new data set

print("Number of unique customers:", len(UK_online_history.CustomerID.unique()))
print("Number of unique invoices:", len(UK_online_history.Invoice.unique()))
print("Number of unique products:", len(UK_online_history.StockCode.unique()))
# Out:
# Number of unique customers: 3891
# Number of unique invoices: 16315
# Number of unique products: 3365

# %%
# we want to aggregate this data, so we have customer level data
# start with calculating the recency, frequency and monteray value for every customer

# %%
# before we do that, we need a new variable - total amount, this is based on price * quantity

UK_online_history["TotalAmount"] = UK_online_history["Quantity"]*UK_online_history["Price"]
# Out:
# /var/folders/8j/7n34843d16760smbwy7x_sxw0000gn/T/ipykernel_1422/1698235766.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_online_history["TotalAmount"] = UK_online_history["Quantity"]*UK_online_history["Price"]

# %%
# check that worked

UK_online_history.sample(5)
# Out:
#        Invoice StockCode  Quantity         InvoiceDate  Price CustomerID  \
# 233657  557954     23245         2 2011-06-23 18:44:00   4.95     u15023
# 512271  580404     23177         8 2011-12-04 12:01:00   2.25     u13596
# 113551  546160     21239        48 2011-03-10 09:49:00   0.72     u15838
# 419526  573481     22726         4 2011-10-31 11:10:00   3.75     u13994
# 128876  547568     22425         3 2011-03-24 09:50:00   4.95     u13341
#
#                Country                 Description  TotalAmount
# 233657  United Kingdom  SET OF 3 REGENCY CAKE TINS         9.90
# 512271  United Kingdom    TREASURE ISLAND BOOK BOX        18.00
# 113551  United Kingdom          PINK  POLKADOT CUP        34.56
# 419526  United Kingdom  ALARM CLOCK BAKELIKE GREEN        15.00
# 128876  United Kingdom       ENAMEL COLANDER CREAM        14.85

# %%
#  Distribution of how many times the customer purchased - this is defined by how many invoices a customer has had

UK_online_history.groupby(['CustomerID']).nunique()['Invoice'].sort_values(ascending = False)
# Out:
# CustomerID
# u12748    202
# u17841    122
# u15311     91
# u14606     90
# u13089     89
#          ...
# u15523      1
# u1552       1
# u15517      1
# u15507      1
# u15562      1
# Name: Invoice, Length: 3891, dtype: int64

# %%
# check that worked

print("# of invoices for customer ID u12748:", len(UK_online_history[UK_online_history.CustomerID == 'u127'].Invoice.unique()))
# Out:
# # of invoices for customer ID u12748: 0

# %%
# save this as a dataframe

customer_frequency = pd.DataFrame(UK_online_history.groupby(['CustomerID']).nunique()['Invoice']).rename(columns = {"Invoice": "Frequency"})

# %%
# check the distribution of our new feature
sns.boxplot(x = customer_frequency.Frequency)
plt.title("Frequency Dist");

# %%
# Distribution of how much the customer spent - this is defined by the sum of total_amount

UK_online_history.groupby(['CustomerID']).sum()["TotalAmount"].sort_values(ascending = False)
# Out:
# CustomerID
# u18102    221190.81
# u1745     180900.65
# u16446    168472.50
# u17511     85922.00
# u12346     77183.60
#             ...
# u14792         6.20
# u16454         5.90
# u16429         4.95
# u14795         4.25
# u13256         0.00
# Name: TotalAmount, Length: 3891, dtype: float64

# %%
# check the output

print("# of invoices for customer ID u18102:", round(UK_online_history[UK_online_history.CustomerID == 'u18102']['TotalAmount'].sum(), 2))
# Out:
# # of invoices for customer ID u18102: 221190.81

# %%
# let's save this as a dataframe

customer_monetary = pd.DataFrame(UK_online_history.groupby(['CustomerID']).sum()["TotalAmount"].sort_values(ascending = False)).rename(columns = {"TotalAmount": "Monetary"})

# %%
# check the distribution of our new feature
sns.boxplot(x = customer_monetary.Monetary)
plt.title("Monetary");

# %%
# Finally let's calculate the Recency of Orders

UK_online_history.groupby(['CustomerID']).max()["InvoiceDate"].sort_values(ascending = False)
# Out:
# CustomerID
# u13113   2011-12-09 12:49:00
# u15804   2011-12-09 12:31:00
# u13777   2011-12-09 12:25:00
# u17581   2011-12-09 12:21:00
# u12748   2011-12-09 12:20:00
#                  ...
# u14729   2010-12-01 12:43:00
# u17968   2010-12-01 12:23:00
# u16583   2010-12-01 12:03:00
# u17908   2010-12-01 11:45:00
# u18074   2010-12-01 09:53:00
# Name: InvoiceDate, Length: 3891, dtype: datetime64[ns]

# %%
# check the date of a user is the same as table above

UK_online_history[UK_online_history.CustomerID == 'u13113']['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
# we calculate recency the difference between the max invoice date and the customer last invoice date
# usually you would use today's date

customer_recency = pd.DataFrame(UK_online_history.groupby(['CustomerID']).max()["InvoiceDate"]).rename(columns = {"InvoiceDate": "Last_Invoice_Date"})
customer_recency['Recency'] = (UK_online_history['InvoiceDate'].max() - customer_recency['Last_Invoice_Date']).astype('timedelta64[D]').astype(int)
customer_recency
# Out:
#              Last_Invoice_Date  Recency
# CustomerID
# u12346     2011-01-18 10:01:00      325
# u12747     2011-12-07 14:34:00        1
# u12748     2011-12-09 12:20:00        0
# u12749     2011-12-06 09:56:00        3
# u1282      2011-12-06 15:12:00        2
# ...                        ...      ...
# u1828      2011-03-07 09:52:00      277
# u18281     2011-06-12 10:53:00      180
# u18282     2011-12-02 11:43:00        7
# u18283     2011-12-06 12:02:00        3
# u18287     2011-10-28 09:29:00       42
#
# [3891 rows x 2 columns]

# %%
# do a manual check, does the recency make sense? 
# drop last invoice date

customer_recency.drop(['Last_Invoice_Date'], axis = 1, inplace = True)

# %%
# Aggregate all the tables together

online_customer_rfm = pd.concat([customer_frequency, customer_monetary, customer_recency], axis=1)
online_customer_rfm
# Out:
#             Frequency  Monetary  Recency
# CustomerID
# u12346              1  77183.60      325
# u12747             11   3763.01        1
# u12748            202  28308.44        0
# u12749              5   2720.63        3
# u1282               4    942.34        2
# ...               ...       ...      ...
# u1828               1    137.00      277
# u18281              1     46.92      180
# u18282              2    127.05        7
# u18283             16   2046.03        3
# u18287              3   1803.28       42
#
# [3891 rows x 3 columns]

# %%
online_customer_rfm.to_pickle("../data/UK_customers_rfm.pkl")
